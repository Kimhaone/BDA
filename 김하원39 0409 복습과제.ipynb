# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#막대그래프

plt.bar(range(5), [10,20,30,40,50])
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(range(5), [10,20,30,40,50])
plt.xticks(range(5), ['a','b','c','d','e'])
# Out:
# ([<matplotlib.axis.XTick at 0x1de13c2dc40>,
#   <matplotlib.axis.XTick at 0x1de13c2dc10>,
#   <matplotlib.axis.XTick at 0x1de13c2d340>,
#   <matplotlib.axis.XTick at 0x1de13afa070>,
#   <matplotlib.axis.XTick at 0x1de13afa7c0>],
#  [Text(0, 0, 'a'),
#   Text(1, 0, 'b'),
#   Text(2, 0, 'c'),
#   Text(3, 0, 'd'),
#   Text(4, 0, 'e')])

# %%
plt.bar(range(5), [10,20,30,40,50], color = 'red', width = 0.6, linewidth = 2)
plt.xticks(range(5), ['a','b','c','d','e'])
# Out:
# ([<matplotlib.axis.XTick at 0x1de13b262e0>,
#   <matplotlib.axis.XTick at 0x1de13b262b0>,
#   <matplotlib.axis.XTick at 0x1de13b15f70>,
#   <matplotlib.axis.XTick at 0x1de13b5c760>,
#   <matplotlib.axis.XTick at 0x1de13b66040>],
#  [Text(0, 0, 'a'),
#   Text(1, 0, 'b'),
#   Text(2, 0, 'c'),
#   Text(3, 0, 'd'),
#   Text(4, 0, 'e')])

# %%
plt.bar(range(5), [10,20,30,40,50], color = ['red','red','blue','orange','green'])
plt.xticks(range(5),['a','b','c','d','e'])
# Out:
# ([<matplotlib.axis.XTick at 0x1de13b8b6a0>,
#   <matplotlib.axis.XTick at 0x1de13b8b670>,
#   <matplotlib.axis.XTick at 0x1de13b801c0>,
#   <matplotlib.axis.XTick at 0x1de13bbcb80>,
#   <matplotlib.axis.XTick at 0x1de13bc6310>],
#  [Text(0, 0, 'a'),
#   Text(1, 0, 'b'),
#   Text(2, 0, 'c'),
#   Text(3, 0, 'd'),
#   Text(4, 0, 'e')])

# %%
#상자그림

x = np.random.normal(2,5,100)
y = np.random.normal(1,6,100)

plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1de13dbff40>,
#   <matplotlib.lines.Line2D at 0x1de13c52280>],
#  'caps': [<matplotlib.lines.Line2D at 0x1de13c52550>,
#   <matplotlib.lines.Line2D at 0x1de13c52820>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1de13dbfc70>],
#  'medians': [<matplotlib.lines.Line2D at 0x1de13c52af0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1de13c52dc0>],
#  'means': []}

# %%
plt.boxplot([x,y])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1de13d16670>,
#   <matplotlib.lines.Line2D at 0x1de13d16940>,
#   <matplotlib.lines.Line2D at 0x1de13d22a60>,
#   <matplotlib.lines.Line2D at 0x1de13d22d60>],
#  'caps': [<matplotlib.lines.Line2D at 0x1de13d16c10>,
#   <matplotlib.lines.Line2D at 0x1de13d16ee0>,
#   <matplotlib.lines.Line2D at 0x1de13d2f070>,
#   <matplotlib.lines.Line2D at 0x1de13d2f340>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1de13d163a0>,
#   <matplotlib.lines.Line2D at 0x1de13d22790>],
#  'medians': [<matplotlib.lines.Line2D at 0x1de13d221f0>,
#   <matplotlib.lines.Line2D at 0x1de13d2f610>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1de13d224c0>,
#   <matplotlib.lines.Line2D at 0x1de13d2f8e0>],
#  'means': []}

# %%
plt.boxplot([x,y])
plt.xticks([1,2], ['a','b'])
# Out:
# ([<matplotlib.axis.XTick at 0x1de13d5da30>,
#   <matplotlib.axis.XTick at 0x1de13d5da00>],
#  [Text(1, 0, 'a'), Text(2, 0, 'b')])

# %%
#히스토그램

x = np.random.normal(5,10,100)

# %%
plt.hist(x)
# Out:
# (array([ 4.,  4.,  9., 20., 27., 19.,  9.,  3.,  3.,  2.]),
#  array([-17.91530604, -12.64531449,  -7.37532294,  -2.10533139,
#           3.16466016,   8.43465171,  13.70464326,  18.97463482,
#          24.24462637,  29.51461792,  34.78460947]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(x, bins = 15)
# Out:
# (array([ 2.,  3.,  3.,  8.,  8., 13., 17., 15., 14.,  6.,  4.,  2.,  3.,
#          0.,  2.]),
#  array([-17.91530604, -14.40197834, -10.88865064,  -7.37532294,
#          -3.86199524,  -0.34866754,   3.16466016,   6.67798786,
#          10.19131556,  13.70464326,  17.21797096,  20.73129867,
#          24.24462637,  27.75795407,  31.27128177,  34.78460947]),
#  <BarContainer object of 15 artists>)

# %%
plt.hist(x, bins = 30)
# Out:
# (array([ 2.,  0.,  2.,  1.,  2.,  1.,  4.,  4.,  1.,  7.,  7.,  6.,  8.,
#          9., 10.,  5.,  8.,  6.,  3.,  3.,  3.,  1.,  1.,  1.,  1.,  2.,
#          0.,  0.,  0.,  2.]),
#  array([-17.91530604, -16.15864219, -14.40197834, -12.64531449,
#         -10.88865064,  -9.13198679,  -7.37532294,  -5.61865909,
#          -3.86199524,  -2.10533139,  -0.34866754,   1.40799631,
#           3.16466016,   4.92132401,   6.67798786,   8.43465171,
#          10.19131556,  11.94797941,  13.70464326,  15.46130711,
#          17.21797096,  18.97463482,  20.73129867,  22.48796252,
#          24.24462637,  26.00129022,  27.75795407,  29.51461792,
#          31.27128177,  33.02794562,  34.78460947]),
#  <BarContainer object of 30 artists>)

# %%
plt.hist(x, bins = 5)
# Out:
# (array([ 8., 29., 46., 12.,  5.]),
#  array([-17.91530604,  -7.37532294,   3.16466016,  13.70464326,
#          24.24462637,  34.78460947]),
#  <BarContainer object of 5 artists>)

# %%
#히트맵

data = pd.DataFrame({'DA': [50,70,80], 'PG': [10,20,30]},
                    index = ['a','b','c'])

# %%
data
# Out:
#    DA  PG
# a  50  10
# b  70  20
# c  80  30

# %%
sns.heatmap(data)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(data, annot=True, fmt = 'd')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(data, annot= True, fmt = 'd', linewidth = 10, linecolor = 'white')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(data, annot=True, fmt='d', linewidth=10,linecolor='white', cmap='Greys')
# Out:
# <AxesSubplot:>

# %%
df_dw = pd.read_csv('재무제표샘플_대원미디어.csv', encoding = 'euc-kr')

# %%
df_dw
# Out:
#      연도          자산총계         부채총계          자본총계           매출액        영업이익  \
# 0  2016  9.776068e+10  23419492827  7.434119e+10  9.499312e+10  2379822965
# 1  2017  1.043490e+11  23398872100  8.095035e+10  1.207350e+11  6987071352
# 2  2018  1.255730e+11  24027374437  1.015450e+11  1.633750e+11  6412992156
# 3  2019  1.361390e+11  34941404675  1.011980e+11  1.915460e+11  3664066464
# 4  2020  1.446900e+11  35459747467  1.092300e+11  2.662270e+11  7227983716
#
#         당기순이익       부채비율
# 0   480426339  76.044057
# 1  7797097354  77.576381
# 2  4153603488  80.865781
# 3  3181392223  74.334031
# 4  6501208590  75.492644

# %%
df_dw.plot(kind = 'line', x = '연도', y = ['영업이익','당기순이익'])
# Out:
# <AxesSubplot:xlabel='연도'>
# C:\Users\onlyo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\onlyo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\onlyo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\onlyo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50629 (\N{HANGUL SYLLABLE EOB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\onlyo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\onlyo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51061 (\N{HANGUL SYLLABLE IG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\onlyo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 45817 (\N{HANGUL SYLLABLE DANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\onlyo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\onlyo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49692 (\N{HANGUL SYLLABLE SUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df_dw.plot(kind = 'bar', x = '연도', y = ['영업이익','당기순이익'],)
# Out:
# <AxesSubplot:xlabel='연도'>
# C:\Users\onlyo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\onlyo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\onlyo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\onlyo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50629 (\N{HANGUL SYLLABLE EOB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\onlyo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\onlyo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51061 (\N{HANGUL SYLLABLE IG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\onlyo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 45817 (\N{HANGUL SYLLABLE DANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\onlyo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\onlyo\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49692 (\N{HANGUL SYLLABLE SUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
mpg = pd.read_csv('mpg.csv')

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
#
# [234 rows x 11 columns]

# %%
mpg.plot(kind = 'line', x = 'year', y = ['cty','hwy'], figsize = (10,7))
# Out:
# <AxesSubplot:xlabel='year'>

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10,8))

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(nrows= 1, ncols= 4, figsize= (10,8))

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10,8))

ax[0].plot(mpg['cty'])
ax[1].hist(mpg['model'].value_counts(), facecolor='red')
# Out:
# (array([1., 4., 4., 6., 5., 9., 3., 4., 1., 1.]),
#  array([ 2. ,  2.9,  3.8,  4.7,  5.6,  6.5,  7.4,  8.3,  9.2, 10.1, 11. ]),
#  <BarContainer object of 10 artists>)

# %%
#반복문

import matplotlib.gridspec as gridspec
grid = gridspec.GridSpec(2,2)
plt.figure(figsize = (16,10))
plt.subplots_adjust(wspace=0.5, hspace = 0.4)

mpg_features = ['manufacturer','model','category','drv']

for idx, feature in enumerate(mpg_features):
    ax = plt.subplot(grid[idx])
    
    sns.countplot(x = feature,
                 data = mpg,
                 hue = 'drv',
                 palette = 'pastel',
                 ax = ax)
    ax.set_title(f'{feature} Distributrion')
