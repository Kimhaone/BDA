# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

titanic = pd.read_csv('titanic.csv')
mpg= pd.read_csv('mpg.csv')

# %%
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10,10))
ax[0].plot(mpg['cty'])
ax[1].plot(mpg['hwy'])
ax[2].hist(mpg['model'].value_counts(), facecolor='red')
ax[3].hist(mpg['trans'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28564\742722838.py in <module>
#       1 fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10,10))
# ----> 2 ax[0].plot(mpg['cty'])
#       3 ax[1].plot(mpg['hwy'])
#       4 ax[2].hist(mpg['model'].value_counts(), facecolor='red')
#       5 ax[3].hist(mpg['trans'].value_counts())
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
fig, ax = plt.subplots(2,2, figsize = (8,10))

ax[0].plot(mpg['hwy'])
ax[1].plot(mpg['cty'])
ax[2].hist(mpg['model'].value_counts(), facecolor='red')
ax[3].hist(mpg['trans'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28564\601086172.py in <module>
#       1 fig, ax = plt.subplots(2,2, figsize = (8,10))
#       2
# ----> 3 ax[0].plot(mpg['hwy'])
#       4 ax[1].plot(mpg['cty'])
#       5 ax[2].hist(mpg['model'].value_counts(), facecolor='red')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'
